# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def dict_to_list(dict):
    list = []
    for key, value in dict.items():
        list.append([key, value])
    return list

# %%
data_file0 = 'usage/gen9ou-0.json'
df0 = pd.read_json(data_file0)
df0 = df0.transpose()
df0 = df0.applymap(lambda cell: dict_to_list(cell) if isinstance(cell, dict) else cell)
df0 = df0.reset_index()
df0.rename(columns = {'index': 'name_pokemon'}, inplace=True)

# %%
df0
# Out:
#      name_pokemon                                              Moves
# 0       Magnemite  [[, 360.0], [terablast, 14.0], [eerieimpulse, ...  \
# 1     Iron Leaves  [[, 27.0], [smartstrike, 205.0], [terablast, 1...
# 2         Zoroark  [[sludgebomb, 1200.0], [, 10.0], [dig, 12.0], ...
# 3        Arboliva  [[, 51.0], [terablast, 2719.0], [rest, 84.0], ...
# 4    Iron Valiant  [[, 473.0], [falseswipe, 8.0], [liquidation, 7...
# ..            ...                                                ...
# 305       Flamigo  [[, 18.0], [liquidation, 1680.0], [terablast, ...
# 306      Gumshoos  [[, 229.0], [facade, 18.0], [terablast, 17.0],...
# 307       Drednaw  [[, 12.0], [smartstrike, 13.0], [liquidation, ...
# 308      Camerupt  [[, 2.0], [firespin, 8.0], [terablast, 209.0],...
# 309    Krookodile  [[, 3.0], [sludgebomb, 31.0], [dig, 109.0], [t...
#
#                                    Checks and Counters
# 0                                                   []  \
# 1    [[Gengar, [65.0, 0.33846153846153804, 0.058691...
# 2    [[Zamazenta, [62.0, 0.854838709677419, 0.04473...
# 3    [[Iron Leaves, [32.0, 0.6875, 0.08193819126329...
# 4    [[Iron Leaves, [637.0, 0.49293563579277805, 0....
# ..                                                 ...
# 305  [[Zamazenta, [88.0, 0.522727272727272, 0.05324...
# 306  [[Gholdengo, [34.0, 0.647058823529411, 0.08195...
# 307  [[Zamazenta, [62.0, 0.693548387096774, 0.05854...
# 308  [[Moltres, [24.0, 0.5, 0.102062072615965]], [I...
# 309  [[Iron Valiant, [351.0, 0.7464387464387461, 0....
#
#                                              Abilities
# 0    [[magnetpull, 52.0], [analytic, 32.0], [sturdy...  \
# 1                              [[quarkdrive, 11849.0]]
# 2                                 [[illusion, 5408.0]]
# 3             [[seedsower, 9627.0], [harvest, 5836.0]]
# 4                             [[quarkdrive, 622587.0]]
# ..                                                 ...
# 305  [[costar, 312.0], [scrappy, 5499.0], [tangledf...
# 306  [[stakeout, 278.0], [strongjaw, 153.0], [adapt...
# 307  [[swiftswim, 2305.0], [shellarmor, 532.0], [st...
# 308  [[solidrock, 780.0], [magmaarmor, 227.0], [ang...
# 309  [[intimidate, 2127.0], [moxie, 4835.0], [anger...
#
#                                              Teammates     usage
# 0    [[Stunky, 32.0], [Bronzong, 4.0], [Mareep, 5.0...  0.000130  \
# 1    [[Wugtrio, 3.0], [Iron Valiant, 3812.0], [Oric...  0.004438
# 2    [[Iron Leaves, 39.0], [Blissey, 44.0], [Wugtri...  0.001976
# 3    [[Magnemite, 16.0], [Iron Leaves, 168.0], [Bli...  0.005741
# 4    [[Eevee, 1.0], [Tornadus, 570.0], [Cresselia, ...  0.236758
# ..                                                 ...       ...
# 305  [[Iron Leaves, 35.0], [Wugtrio, 38.0], [Bronzo...  0.002196
# 306  [[Iron Leaves, 1.0], [Arboliva, 5.0], [Iron Va...  0.000242
# 307  [[Zoroark, 9.0], [Arboliva, 8.0], [Iron Valian...  0.001611
# 308  [[Hattrem, 8.0], [Gengar, 24.0], [Iron Valiant...  0.000400
# 309  [[Iron Leaves, 57.0], [Wugtrio, 16.0], [Primea...  0.002678
#
#                                                  Items  Raw count
# 0    [[metalcoat, 2.0], [mentalherb, 1.0], [rockyhe...        374  \
# 1    [[scopelens, 86.0], [ejectbutton, 1.0], [rocky...      11849
# 2    [[scopelens, 3.0], [focusband, 2.0], [choplebe...       5408
# 3    [[petayaberry, 52.0], [chopleberry, 32.0], [me...      15463
# 4    [[petayaberry, 4.0], [figyberry, 20.0], [zooml...     622587
# ..                                                 ...        ...
# 305  [[blunderpolicy, 5.0], [psychicseed, 4.0], [ro...       5932
# 306  [[chopleberry, 2.0], [rockyhelmet, 3.0], [focu...        663
# 307  [[mentalherb, 10.0], [salacberry, 4.0], [rocky...       4381
# 308  [[scopelens, 15.0], [rockyhelmet, 47.0], [focu...       1103
# 309  [[metalcoat, 2.0], [scopelens, 8.0], [choplebe...       7311
#
#                                                Spreads          Happiness
# 0    [[Hardy:0/248/0/72/0/0, 3.0], [Adamant:4/252/0...     [[255, 374.0]]  \
# 1    [[Jolly:96/160/0/0/0/252, 1933.0], [Hardy:0/25...   [[255, 11849.0]]
# 2    [[Modest:12/0/0/244/0/252, 5.0], [Hardy:252/0/...    [[255, 5408.0]]
# 3    [[Quiet:252/0/132/124/0/0, 2.0], [Hardy:0/252/...   [[255, 15463.0]]
# 4    [[Hardy:0/252/0/0/0/252, 153.0], [Naive:112/16...  [[255, 622587.0]]
# ..                                                 ...                ...
# 305  [[Jolly:96/252/0/0/0/160, 5.0], [Adamant:0/252...    [[255, 5932.0]]
# 306  [[Adamant:4/252/0/0/0/252, 13.0], [Hardy:60/25...     [[255, 663.0]]
# 307  [[Adamant:96/252/0/0/0/160, 7.0], [Hardy:252/1...    [[255, 4381.0]]
# 308  [[Hardy:184/168/156/0/0/0, 7.0], [Quiet:248/0/...    [[255, 1103.0]]
# 309  [[Hardy:0/36/112/0/108/252, 34.0], [Jolly:96/2...    [[255, 7311.0]]
#
#        Viability Ceiling
# 0       [93, 57, 57, 45]
# 1     [1620, 85, 74, 57]
# 2      [591, 74, 68, 52]
# 3     [1589, 85, 71, 54]
# 4    [35959, 89, 80, 63]
# ..                   ...
# 305    [637, 83, 74, 55]
# 306    [119, 76, 67, 53]
# 307    [631, 78, 73, 55]
# 308    [204, 78, 68, 50]
# 309    [904, 73, 66, 52]
#
# [310 rows x 11 columns]

# %%
data_file1 = 'usage/gen9ou-0.json'
df1 = pd.read_json(data_file1)
df1 = df1.transpose()
df1 = df1.applymap(lambda cell: dict_to_list(cell) if isinstance(cell, dict) else cell)
df1 = df1.reset_index()
df1.rename(columns = {'index': 'name_pokemon'}, inplace=True)

df1 = df1.loc[:, ['name_pokemon', 'usage']]

# %%
df1
# Out:
#      name_pokemon     usage
# 0       Magnemite  0.000130
# 1     Iron Leaves  0.004438
# 2         Zoroark  0.001976
# 3        Arboliva  0.005741
# 4    Iron Valiant  0.236758
# ..            ...       ...
# 305       Flamigo  0.002196
# 306      Gumshoos  0.000242
# 307       Drednaw  0.001611
# 308      Camerupt  0.000400
# 309    Krookodile  0.002678
#
# [310 rows x 2 columns]

# %%
def calcul_occurence(list, index_occurence, usage_column = True, usage_occurence_ratio = 4): #index_occurence est l'indice dans la une sous-liste de la valeur permettant de calculer l'occurence
    occurence = 0
    for sublist in list:
        """print(sublist)
        print(sublist[index_occurence])"""
        occurence += sublist[index_occurence]
    for sublist in list:
        sublist.append(sublist[index_occurence]/occurence)
    if usage_column:
        for sublist in list:
            sublist.append(usage_occurence_ratio*sublist[-1])
    return list

# %%
data_file2 = 'usage/gen9ou-0.json'
df2 = pd.read_json(data_file2)
df2 = df2.transpose()
df2 = df2.applymap(lambda cell: dict_to_list(cell) if isinstance(cell, dict) else cell)
df2 = df2.reset_index()
df2.rename(columns = {'index': 'name_pokemon'}, inplace=True)
for i in range(len(df2)):
    df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)

df2_expanded = df2.explode('Moves')[['name_pokemon', 'Moves']]
df2_expanded['Moves name'] = df2_expanded['Moves'].apply(lambda x: x[0])
df2_expanded['Moves occurence'] = df2_expanded['Moves'].apply(lambda x: x[2])
df2_expanded['Moves usage'] = df2_expanded['Moves'].apply(lambda x: x[3])
df2_expanded.reset_index(inplace=True, drop=True)
df2_expanded = df2_expanded[['name_pokemon', 'Moves name', 'Moves occurence', 'Moves usage']]
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\2567941885.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Moves'].iloc[i] = calcul_occurence(df2['Moves'].iloc[i], 1)

# %%
df2_expanded
# Out:
#       name_pokemon    Moves name  Moves occurence  Moves usage
# 0        Magnemite                       0.240642     0.962567
# 1        Magnemite     terablast         0.009358     0.037433
# 2        Magnemite  eerieimpulse         0.010027     0.040107
# 3        Magnemite          rest         0.006016     0.024064
# 4        Magnemite     steelbeam         0.029412     0.117647
# ...            ...           ...              ...          ...
# 14973   Krookodile    doubleedge         0.001265     0.005061
# 14974   Krookodile        thrash         0.000205     0.000821
# 14975   Krookodile      sandtomb         0.000821     0.003283
# 14976   Krookodile     stoneedge         0.060662     0.242648
# 14977   Krookodile      firefang         0.013473     0.053891
#
# [14978 rows x 4 columns]

# %%
data_file3 = 'usage/gen9ou-0.json'
df3 = pd.read_json(data_file3)
df3 = df3.transpose()
df3 = df3.applymap(lambda cell: dict_to_list(cell) if isinstance(cell, dict) else cell)
df3 = df3.reset_index()
df3.rename(columns = {'index': 'name_pokemon'}, inplace=True)
for i in range(len(df3)):
    df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1, usage_occurence_ratio=1)

df3_expanded = df3.explode('Abilities')[['name_pokemon', 'Abilities']]
df3_expanded['Ability name'] = df3_expanded['Abilities'].apply(lambda x: x[0])
df3_expanded['Ability occurence'] = df3_expanded['Abilities'].apply(lambda x: x[2])
df3_expanded['Ability usage'] = df3_expanded['Abilities'].apply(lambda x: x[3])
df3_expanded.reset_index(inplace=True, drop=True)
df3_expanded = df3_expanded[['name_pokemon', 'Ability name', 'Ability occurence', 'Ability usage']]
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)
# C:\Users\franc\AppData\Local\Temp\ipykernel_28548\1559988570.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Abilities'].iloc[i] = calcul_occurence(df3['Abilities'].iloc[i], 1)

# %%
df3_expanded
# Out:
#     name_pokemon Ability name  Ability occurence  Ability usage
# 0      Magnemite   magnetpull           0.139037       0.556150
# 1      Magnemite     analytic           0.085561       0.342246
# 2      Magnemite       sturdy           0.775401       3.101604
# 3    Iron Leaves   quarkdrive           1.000000       4.000000
# 4        Zoroark     illusion           1.000000       4.000000
# ..           ...          ...                ...            ...
# 685     Camerupt   magmaarmor           0.205802       0.823209
# 686     Camerupt   angerpoint           0.087035       0.348141
# 687   Krookodile   intimidate           0.290931       1.163726
# 688   Krookodile        moxie           0.661332       2.645329
# 689   Krookodile   angerpoint           0.047736       0.190945
#
# [690 rows x 4 columns]

# %%
from sqlalchemy import create_engine


path = 'stats_pokemons/'
database = path + 'stats_pokemons.db'
engine = create_engine('sqlite:///' + database)
df1.to_sql("Pokemons usage", engine, index=False, if_exists='replace')
df2_expanded.to_sql("Moves usage", engine, index=False, if_exists='replace')
df3_expanded.to_sql("Abilities usage", engine, index=False, if_exists='replace')
# Out:
# 690
