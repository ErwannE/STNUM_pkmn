# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def dict_to_list(dict):
    list = []
    for key, value in dict.items():
        list.append([key, value])
    return list

# %%
data_file = 'usage/gen9ou-0.json'
df = pd.read_json(data_file)
df = df.transpose()
df = df.applymap(lambda cell: dict_to_list(cell) if isinstance(cell, dict) else cell)
df = df.loc[:, ['Moves', 'Abilities', 'usage']]

# %%
"""data_file = 'stats_pokemons/gen01.csv'
df = pd.read_csv(data_file)"""
# Out:
# "data_file = 'stats_pokemons/gen01.csv'\ndf = pd.read_csv(data_file)"

# %%
df
# Out:
#                                                           Moves
# Magnemite     [[, 360.0], [terablast, 14.0], [eerieimpulse, ...  \
# Iron Leaves   [[, 27.0], [smartstrike, 205.0], [terablast, 1...
# Zoroark       [[sludgebomb, 1200.0], [, 10.0], [dig, 12.0], ...
# Arboliva      [[, 51.0], [terablast, 2719.0], [rest, 84.0], ...
# Iron Valiant  [[, 473.0], [falseswipe, 8.0], [liquidation, 7...
# ...                                                         ...
# Flamigo       [[, 18.0], [liquidation, 1680.0], [terablast, ...
# Gumshoos      [[, 229.0], [facade, 18.0], [terablast, 17.0],...
# Drednaw       [[, 12.0], [smartstrike, 13.0], [liquidation, ...
# Camerupt      [[, 2.0], [firespin, 8.0], [terablast, 209.0],...
# Krookodile    [[, 3.0], [sludgebomb, 31.0], [dig, 109.0], [t...
#
#                                                       Abilities     usage
# Magnemite     [[magnetpull, 52.0], [analytic, 32.0], [sturdy...  0.000130
# ...

# %%
def info_pokemon(name):
    return df[name]['Moves']
info_pokemon('Magnemite')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\franc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\franc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\franc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Magnemite'
#
# ...

# %%
n = len(df.iloc[4])
X=range(n)
Y=[df.iloc[4][x] for x in X]
plt.plot(X,Y)
plt.show()

# %%
df.iloc[2][0]
# Out:
# [['magnetpull', 52.0], ['analytic', 32.0], ['sturdy', 290.0]]

# %%
list(df.iloc[0][0].items())[0][0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 list(df.iloc[0][0].items())[0][0]
#
# AttributeError: 'list' object has no attribute 'items'
